# %%
import pandas as pd

# %%
std_data_path = "download.csv"

# %%
std_data = pd.read_csv(std_data_path)

# %%
std_data = std_data.iloc[:,1:]

# %%
std_data
# Out:
#            Username      Classroom Language  Streak  Days active  Total XP  \
# 0       Da_joker360  Premium Class   Arabic       0            4      3004
# 1       FaroukMusa1  Premium Class  Spanish       0          101      7083
# 2       Yipmong2020  Premium Class   Arabic       0            0         0
# 3  Syed_Hassaan_420  Premium Class   Arabic     162           97     14049
# 4       WalterTron3  Premium Class   German     122           31      7941
# 5       Waltertron6  Premium Class  English       0            0         0
# 6           Yipmong  Premium Class      NaN     286          221    168136
# 7         fayalicha  Premium Class  English       0            0         0
# 8       lazypillow3  Premium Class  Spanish       0           20      1229
#
#   Time Spent Learning  Ramp Up Challenge  Lessons  Level Review  Writing  \
# 0               2h 1m                 31       21             4        0
# ...
