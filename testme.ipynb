# %%
import pandas as pd

# %%
std_data_path = "download.csv"

# %%
std_data = pd.read_csv(std_data_path)

# %%
std_data = std_data.iloc[:,1:]

# %%
std_data
# Out:
#            Username                             Email      Classroom Language  \
# 0       Da_joker360              realatm360@gmail.com  Premium Class   Arabic
# 1       FaroukMusa1         faroukmusatukur@gmail.com  Premium Class  Spanish
# 2       Yipmong2020        said2@schools.duolingo.com  Premium Class   Arabic
# 3  Syed_Hassaan_420          syedhassaan720@gmail.com  Premium Class   Arabic
# 4       WalterTron3         waltertronics02@gmail.com  Premium Class   German
# 5       Waltertron6  Waltertron6@schools.duolingo.com  Premium Class  English
# 6           Yipmong               syipmong5@gmail.com  Premium Class      NaN
# 7         fayalicha     learn.informatique7@gmail.com  Premium Class  English
# 8       lazypillow3           successp50001@gmail.com  Premium Class  Spanish
#
#    Streak  Days active  Total XP Time Spent Learning  Ramp Up Challenge  \
# 0       0            4      3004               2h 1m                 31
# ...
