# %%
import pandas as pd

# %%
std_data_path = "data_visualization/Top-100 Trending Books.csv"

# %%
std_data = pd.read_csv(std_data_path)

# %%
std_data = std_data.iloc[:,1:]

# %%
std_data
# Out:
#                                            book title  book price  rating  \
# 0                        Iron Flame (The Empyrean, 2)       18.42     4.1
# 1                                     The Woman in Me       20.93     4.5
# 2                                   My Name Is Barbra       31.50     4.5
# 3   Friends, Lovers, and the Big Terrible Thing: A...       23.99     4.4
# 4                               How to Catch a Turkey        5.65     4.8
# ..                                                ...         ...     ...
# 95  First Little Readers Parent Pack: Guided Readi...       11.40     4.7
# 96                                            Hatchet        5.14     4.7
# 97  The Wager: A Tale of Shipwreck, Mutiny and Murder       15.30     4.5
# 98  I'm Dead, Now What?: Important Information Abo...       12.99     4.6
# 99                                   The Wonky Donkey        5.28     4.8
#
#                 author  year of publication  \
# ...
